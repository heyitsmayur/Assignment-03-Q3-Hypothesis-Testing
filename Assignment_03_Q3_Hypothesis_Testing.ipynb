# %% [markdown]
# Q3.

# %% [markdown]
# ![Screenshot 2023-03-11 151637.png](data:image/png;base64,...)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8c8de6fd-c1ef-4774-962b-e4b76d6f824d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c8de6fd-c1ef-4774-962b-e4b76d6f824d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data3 = pd.read_csv('BuyerRatio.csv')
data3
# Out:
#   Observed Values  East  West  North  South
# 0           Males    50   142    131     70
# 1         Females   435  1523   1356    750

# %%
Mdata = np.array([data3.iloc[0,1:],data3.iloc[1,1:]])
Mdata
# Out:
# array([[50, 142, 131, 70],
#        [435, 1523, 1356, 750]], dtype=object)

# %%
from scipy.stats import chi2_contingency

# %%
chi2_contingency(Mdata)
# Out:
# Chi2ContingencyResult(statistic=1.595945538661058, pvalue=0.6603094907091882, dof=3, expected_freq=array([[  42.76531299,  146.81287862,  131.11756787,   72.30424052],
#        [ 442.23468701, 1518.18712138, 1355.88243213,  747.69575948]]))

# %%
alpha=0.05

# %%
if p > alpha:
  print("male-female buyer rations are similar across regions")
else:
  print("male-female buyer rations are NOT similar across regions")
# Out:
# male-female buyer rations are similar across regions
